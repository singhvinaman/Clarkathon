# %% [markdown]
# <a href="https://colab.research.google.com/github/singhvinaman/Clarkathon/blob/main/Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/karpathy/nanoGPT.git
# Out:
# Cloning into 'nanoGPT'...
# remote: Enumerating objects: 682, done.
# remote: Total 682 (delta 0), reused 0 (delta 0), pack-reused 682 (from 1)
# Receiving objects: 100% (682/682), 952.47 KiB | 1.42 MiB/s, done.
# Resolving deltas: 100% (385/385), done.

# %%
# !pip install numpy cohere openai transformers datasets tiktoken wandb tqdm
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Collecting cohere
#   Downloading cohere-5.13.3-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.5)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.3)
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Collecting tiktoken
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.18.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere)
#   Downloading fastavro-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: httpx>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.28.0)
# Collecting httpx-sse==0.4.0 (from cohere)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting parameterized<0.10.0,>=0.9.0 (from cohere)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pydantic>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.10.3)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.27.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.32.3)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.20.3)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere)
#   Downloading types_requests-2.32.0.20241016-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.9)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (4.25.5)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.19.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.21.2->cohere) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.2->cohere) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Downloading cohere-5.13.3-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 12.7 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 32.9 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.8 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.8 MB/s eta 0:00:00
# Downloading fastavro-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 83.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.2 MB/s eta 0:00:00
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading types_requests-2.32.0.20241016-py3-none-any.whl (15 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.0 MB/s eta 0:00:00
# Installing collected packages: xxhash, types-requests, parameterized, httpx-sse, fsspec, fastavro, dill, tiktoken, multiprocess, cohere, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed cohere-5.13.3 datasets-3.1.0 dill-0.3.8 fastavro-1.9.7 fsspec-2024.9.0 httpx-sse-0.4.0 multiprocess-0.70.16 parameterized-0.9.0 tiktoken-0.8.0 types-requests-2.32.0.20241016 xxhash-3.5.0

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
# !python /content/nanoGPT/data/lyrics/prepare.py
# Out:
# length of dataset in characters: 1,115,394
# all the unique characters:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65
# train has 1,003,854 tokens
# val has 111,540 tokens

# %%
# !python /content/nanoGPT/train.py /content/nanoGPT/config/train_lyrics.py
# Out:
# Overriding config with /content/nanoGPT/config/train_lyrics.py:
# # train a miniature character-level shakespeare model
# # good for debugging and playing on macbooks and such
# out_dir = 'out-lyrics'
# eval_interval = 250 # keep frequent because we'll overfit
# eval_iters = 20
# log_interval = 1 # don't print too often
# # we expect to overfit on this small dataset, so only save when val improves
# always_save_checkpoint = False
# wandb_log = False # override via command line if you like
# wandb_project = 'lyrics'
# wandb_run_name = 'mini-gpt'
# dataset = 'lyrics'
# batch_size = 12
# block_size = 64  # context of up to 256 previous characters
# # baby GPT model :)
# n_layer = 4
# n_head = 4
# n_embd = 128
# dropout = 0
# learning_rate = 1e-3 # with baby networks can afford to go a bit higher
# max_iters = 200
# lr_decay_iters = 200 # make equal to max_iters usually
# min_lr = 1e-4 # learning_rate / 10 usually
# beta2 = 0.99 # make a bit bigger because number of tokens per iter is small
# warmup_iters = 100 # not super necessary potentially
# # on macbook also add
# # device = 'cpu' # run on cpu only
# # compile = False # do not torch compile the model
# tokens per iteration will be: 30,720
# Initializing a new model from scratch
# defaulting to vocab_size of GPT-2 to 50304 (50257 rounded up for efficiency)
# number of parameters: 7.23M
# /content/nanoGPT/train.py:199: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# num decayed parameter tensors: 18, with 7,233,536 parameters
# num non-decayed parameter tensors: 9, with 1,152 parameters
# using fused AdamW: True
# compiling the model... (takes a ~minute)
# /usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py:1604: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] WON'T CONVERT forward /content/nanoGPT/model.py line 103
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] due to:
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] Traceback (most recent call last):
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1446, in _call_user_compiler
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 129, in __call__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 2234, in __call__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1521, in compile_fx
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return aot_autograd(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/backends/common.py", line 72, in __call__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 1071, in aot_module_simplified
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 1056, in dispatch_and_compile
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 522, in create_aot_dispatcher_function
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1350, in fw_compiler_base
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1421, in _fw_compiler_base
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return inner_compile(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 475, in compile_fx_inner
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_aot.py", line 85, in debug_wrapper
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 661, in _compile_fx_inner
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 1334, in load
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 570, in codegen_and_compile
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 878, in fx_codegen_and_compile
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1913, in compile_to_fn
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return self.compile_to_module().call
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1839, in compile_to_module
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return self._compile_to_module()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1845, in _compile_to_module
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1780, in codegen
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1731, in __init__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self._init(nodes)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1749, in _init
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1749, in <listcomp>
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1856, in create_scheduler_node
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return SchedulerNode(self, node)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 833, in __init__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self._compute_attrs()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 846, in _compute_attrs
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 3360, in get_backend
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 3352, in create_backend
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     raise RuntimeError(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] Traceback (most recent call last):
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 1064, in __call__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     result = self._inner_convert(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 526, in __call__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return _compile(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 924, in _compile
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 666, in compile_inner
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_utils_internal.py", line 87, in wrapper_function
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return function(*args, **kwargs)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 699, in _compile_inner
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1322, in transform_code_object
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     transformations(instructions, code_options)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 219, in _fn
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return fn(*args, **kwargs)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 634, in transform
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     tracer.run()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2796, in run
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     super().run()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 983, in run
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     while self.step():
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 895, in step
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2987, in RETURN_VALUE
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self._return(inst)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2972, in _return
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.output.compile_subgraph(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1117, in compile_subgraph
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1369, in compile_and_call_fx_graph
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1416, in call_user_compiler
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return self._call_user_compiler(gm)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1465, in _call_user_compiler
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] Traceback (most recent call last):
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1446, in _call_user_compiler
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 129, in __call__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 2234, in __call__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1521, in compile_fx
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return aot_autograd(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/backends/common.py", line 72, in __call__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 1071, in aot_module_simplified
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 1056, in dispatch_and_compile
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 522, in create_aot_dispatcher_function
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1350, in fw_compiler_base
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1421, in _fw_compiler_base
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return inner_compile(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 475, in compile_fx_inner
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_aot.py", line 85, in debug_wrapper
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 661, in _compile_fx_inner
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 1334, in load
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 570, in codegen_and_compile
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 878, in fx_codegen_and_compile
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1913, in compile_to_fn
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return self.compile_to_module().call
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1839, in compile_to_module
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return self._compile_to_module()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1845, in _compile_to_module
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1780, in codegen
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1731, in __init__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self._init(nodes)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1749, in _init
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1749, in <listcomp>
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1856, in create_scheduler_node
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return SchedulerNode(self, node)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 833, in __init__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self._compute_attrs()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 846, in _compute_attrs
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 3360, in get_backend
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 3352, in create_backend
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     raise RuntimeError(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] Traceback (most recent call last):
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 1064, in __call__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     result = self._inner_convert(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 526, in __call__
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return _compile(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 924, in _compile
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 666, in compile_inner
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_utils_internal.py", line 87, in wrapper_function
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return function(*args, **kwargs)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 699, in _compile_inner
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1322, in transform_code_object
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     transformations(instructions, code_options)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 219, in _fn
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return fn(*args, **kwargs)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 634, in transform
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     tracer.run()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2796, in run
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     super().run()
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 983, in run
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     while self.step():
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 895, in step
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2987, in RETURN_VALUE
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self._return(inst)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2972, in _return
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.output.compile_subgraph(
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1117, in compile_subgraph
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1369, in compile_and_call_fx_graph
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1416, in call_user_compiler
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     return self._call_user_compiler(gm)
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1465, in _call_user_compiler
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1209 17:17:52.119000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] WON'T CONVERT forward /content/nanoGPT/model.py line 26
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] due to:
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] Traceback (most recent call last):
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1446, in _call_user_compiler
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 129, in __call__
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 2234, in __call__
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1521, in compile_fx
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return aot_autograd(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/backends/common.py", line 72, in __call__
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 1071, in aot_module_simplified
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 1056, in dispatch_and_compile
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 522, in create_aot_dispatcher_function
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1350, in fw_compiler_base
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 1421, in _fw_compiler_base
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return inner_compile(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 475, in compile_fx_inner
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_aot.py", line 85, in debug_wrapper
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 661, in _compile_fx_inner
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 1334, in load
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 570, in codegen_and_compile
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 878, in fx_codegen_and_compile
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1913, in compile_to_fn
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return self.compile_to_module().call
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1839, in compile_to_module
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return self._compile_to_module()
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1845, in _compile_to_module
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1780, in codegen
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1731, in __init__
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self._init(nodes)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1749, in _init
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1749, in <listcomp>
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1856, in create_scheduler_node
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return SchedulerNode(self, node)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 833, in __init__
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self._compute_attrs()
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 846, in _compute_attrs
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 3360, in get_backend
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 3352, in create_backend
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     raise RuntimeError(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] Traceback (most recent call last):
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 1064, in __call__
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     result = self._inner_convert(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 526, in __call__
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return _compile(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 924, in _compile
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 666, in compile_inner
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_utils_internal.py", line 87, in wrapper_function
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return function(*args, **kwargs)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 699, in _compile_inner
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1322, in transform_code_object
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     transformations(instructions, code_options)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 219, in _fn
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return fn(*args, **kwargs)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 634, in transform
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     tracer.run()
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2796, in run
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     super().run()
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 983, in run
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     while self.step():
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 895, in step
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2987, in RETURN_VALUE
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self._return(inst)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2972, in _return
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.output.compile_subgraph(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1117, in compile_subgraph
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1369, in compile_and_call_fx_graph
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1416, in call_user_compiler
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return self._call_user_compiler(gm)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1465, in _call_user_compiler
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] Traceback (most recent call last):
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1446, in _call_user_compiler
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 129, in __call__
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# ...
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/repro/after_aot.py", line 85, in debug_wrapper
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 661, in _compile_fx_inner
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 1334, in load
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 570, in codegen_and_compile
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py", line 878, in fx_codegen_and_compile
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1913, in compile_to_fn
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return self.compile_to_module().call
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1839, in compile_to_module
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return self._compile_to_module()
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1845, in _compile_to_module
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/graph.py", line 1780, in codegen
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1731, in __init__
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self._init(nodes)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1749, in _init
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1749, in <listcomp>
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 1856, in create_scheduler_node
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return SchedulerNode(self, node)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 833, in __init__
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self._compute_attrs()
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 846, in _compute_attrs
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 3360, in get_backend
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/scheduler.py", line 3352, in create_backend
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     raise RuntimeError(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] Traceback (most recent call last):
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 1064, in __call__
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     result = self._inner_convert(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 526, in __call__
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return _compile(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 924, in _compile
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 666, in compile_inner
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_utils_internal.py", line 87, in wrapper_function
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return function(*args, **kwargs)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 699, in _compile_inner
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1322, in transform_code_object
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     transformations(instructions, code_options)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 219, in _fn
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return fn(*args, **kwargs)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 634, in transform
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     tracer.run()
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2796, in run
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     super().run()
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 983, in run
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     while self.step():
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 895, in step
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2987, in RETURN_VALUE
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self._return(inst)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/symbolic_convert.py", line 2972, in _return
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.output.compile_subgraph(
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1117, in compile_subgraph
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1369, in compile_and_call_fx_graph
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1416, in call_user_compiler
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     return self._call_user_compiler(gm)
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py", line 1465, in _call_user_compiler
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W1209 17:17:52.227000 4604 torch/_dynamo/convert_frame.py:1125]
# /usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py:1604: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/_inductor/compile_fx.py:1604: UserWarning: Tesla T4 does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# step 0: train loss 10.7962, val loss 10.7946
# iter 0: loss 10.8066, time 7008.05ms, mfu -100.00%
# iter 1: loss 10.8141, time 882.44ms, mfu -100.00%
# iter 2: loss 10.7706, time 956.83ms, mfu -100.00%
# iter 3: loss 10.7450, time 948.12ms, mfu -100.00%
# iter 4: loss 10.6800, time 947.40ms, mfu -100.00%
# iter 5: loss 10.5924, time 949.86ms, mfu 0.45%
# iter 6: loss 10.4842, time 951.14ms, mfu 0.45%
# iter 7: loss 10.3808, time 953.33ms, mfu 0.45%
# iter 8: loss 10.3258, time 953.27ms, mfu 0.45%
# iter 9: loss 10.2618, time 950.76ms, mfu 0.45%
# iter 10: loss 10.2047, time 951.02ms, mfu 0.45%
# iter 11: loss 10.1386, time 954.16ms, mfu 0.45%
# iter 12: loss 10.1544, time 953.81ms, mfu 0.45%
# iter 13: loss 10.0063, time 959.22ms, mfu 0.45%
# iter 14: loss 10.0296, time 944.88ms, mfu 0.45%
# iter 15: loss 9.9574, time 950.70ms, mfu 0.45%
# iter 16: loss 9.9878, time 955.96ms, mfu 0.45%
# iter 17: loss 9.8937, time 952.75ms, mfu 0.45%
# iter 18: loss 9.8618, time 957.05ms, mfu 0.45%
# iter 19: loss 9.8451, time 958.70ms, mfu 0.45%
# iter 20: loss 9.7699, time 956.37ms, mfu 0.45%
# iter 21: loss 9.7580, time 954.60ms, mfu 0.45%
# iter 22: loss 9.6584, time 956.81ms, mfu 0.45%
# iter 23: loss 9.6285, time 955.62ms, mfu 0.45%
# iter 24: loss 9.5943, time 958.09ms, mfu 0.45%
# iter 25: loss 9.4814, time 958.25ms, mfu 0.45%
# iter 26: loss 9.3945, time 960.67ms, mfu 0.45%
# iter 27: loss 9.3764, time 962.23ms, mfu 0.45%
# iter 28: loss 9.2936, time 960.85ms, mfu 0.45%
# iter 29: loss 9.2303, time 953.10ms, mfu 0.45%
# iter 30: loss 9.1415, time 959.86ms, mfu 0.45%
# iter 31: loss 9.0262, time 960.78ms, mfu 0.45%
# iter 32: loss 8.9762, time 960.00ms, mfu 0.45%
# iter 33: loss 8.8858, time 963.14ms, mfu 0.45%
# iter 34: loss 8.8256, time 958.82ms, mfu 0.45%
# iter 35: loss 8.6870, time 964.84ms, mfu 0.45%
# iter 36: loss 8.5889, time 960.01ms, mfu 0.45%
# iter 37: loss 8.5046, time 966.56ms, mfu 0.45%
# iter 38: loss 8.4003, time 962.29ms, mfu 0.45%
# iter 39: loss 8.2750, time 966.03ms, mfu 0.45%
# iter 40: loss 8.1871, time 974.67ms, mfu 0.45%
